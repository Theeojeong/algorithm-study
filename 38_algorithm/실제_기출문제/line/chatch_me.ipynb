# %% [markdown]
# <img src="../../../image/catch_me.png" width="600">

# %%
1  2   3   4   5    6
c c+1 c+3 c+6 c+10 c+15
 1   2   3   4    5


n초일 때 이전 상태의 n-1을 더한 값이 n초일 때의(현재) 위치

array = [
    1: c, # 11
    2: c+1, # 12
    3: c+3, # 14
    4: c+6,
    5: c+10
    ]

c = 11
array[n] = array[n-1] + n-1 -> n초일 때 c의 위치

# %%
from collections import deque

c = 11
b = 2


def catch_me(cony_loc, brown_loc):

    
    
    


    return

# %%
print(catch_me(c, b))  # 5가 나와야 합니다!

print("정답 = 3 / 현재 풀이 값 = ", catch_me(10, 3))
print("정답 = 8 / 현재 풀이 값 = ", catch_me(51, 50))
print("정답 = 28 / 현재 풀이 값 = ", catch_me(550, 500))
