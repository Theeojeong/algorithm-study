# %%
# 1 1 2 3
# fib(1) = 1
# fib(2) = 1
# fib(3) = fib(1) + fib(2) # 2
# fib(4) = fig(2) + fib(3) # 3

# fig(n) = fib(n-1) + fib(n-2)

def fibo_recursion(n):
    if n == 1 or n == 2:
        return 1
    return fibo_recursion(n-1) + fibo_recursion(n-2)

# %%
fibo_recursion(50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fibo_recursion(50)
#
# Cell In[2], line 12, in fibo_recursion(n)
#      10 if n == 1 or n == 2:
#      11     return 1
# ---> 12 return fibo_recursion(n-1) + fibo_recursion(n-2)
#
# Cell In[2], line 12, in fibo_recursion(n)
#      10 if n == 1 or n == 2:
#      11     return 1
# ---> 12 return fibo_recursion(n-1) + fibo_recursion(n-2)
#
#     [... skipping similar frames: fibo_recursion at line 12 (31 times)]
#
# Cell In[2], line 12, in fibo_recursion(n)
#      10 if n == 1 or n == 2:
#      11     return 1
# ---> 12 return fibo_recursion(n-1) + fibo_recursion(n-2)
#
# Cell In[2], line 9, in fibo_recursion(n)
#       1 # 1 1 2 3
#       2 # fib(1) = 1
#       3 # fib(2) = 1
#    (...)      6
#       7 # fig(n) = fib(n-1) + fib(n-2)
# ----> 9 def fibo_recursion(n):
#      10     if n == 1 or n == 2:
# ...
