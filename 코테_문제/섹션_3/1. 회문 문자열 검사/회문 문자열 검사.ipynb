# %% [markdown]
# ### 파이썬스럽게

# %%
import sys
sys.stdin=open("in1.txt", "rt")

N = int(input())


for i in range(1, N+1):
    x = input()
    if x == 'q':
        break
    x = x.upper()

    y = []

    for j in x:
        y.append(j)
    
    if y == y[::-1]:
        print(f"#{i} YES")
    else:
        print(f"#{i} NO")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.stdin=open("in1.txt", "rt")
# ----> 4 N = int(input())
#       7 for i in range(1, N+1):
#       8     x = input()
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### 강사님 버전

# %%
N = int(input())

for i in range(N):
    x = input()
    if x == 'q':
        break
    x = x.upper()
    # print(x)
    for j in range(len(x)//2):
        if x[j]!=x[-1-j]:
            print(f"#{i+1} NO")
            break
    else:
        print(f"#{i+1} YES")
# Out:
# #1 YES
