# %%
print("Hello World!")
# Out:
# Hello World!

# %%
from datetime import datetime
import pytz

# Get current date and time in Seoul
seoul_tz = pytz.timezone('Asia/Seoul')
seoul_time = datetime.now(seoul_tz)

print(f"서울의 오늘 날짜: {seoul_time.strftime('%Y년 %m월 %d일')}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from datetime import datetime
# ----> 2 import pytz
#       4 # Get current date and time in Seoul
#       5 seoul_tz = pytz.timezone('Asia/Seoul')
#
# ModuleNotFoundError: No module named 'pytz'

# %%
from datetime import datetime

date = datetime.now().date()
print(date)
# Out:
# 2025-11-07

# %%
print(5)
print("wogusto12")
# Out:
# 5
# wogusto12

# %%
print("\\    /\\")
print(" )  ( ')")
print("(  /  )")
print(" \\(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
print("\\    /\\")
print(" )  ( ')")
print("(  /  )")
print(" \\(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
print("|\\_/|")
print("|q p|   /}")
print("( 0 )\"\"\"\\")      
print("|\"^\"`    |")
print("||_/=\\\\__|")
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|

# %%
print("          ,r'\"7")
print("r`-_   ,'   ,/")
print(" \\. \". L_r'")  
print("   `~\\/")
print("      |")
print("      |")
# Out:
#           ,r'"7
# r`-_   ,'   ,/
#  \. ". L_r'
#    `~\/
#       |
#       |

# %%
print("""         ,r'"7
r`-_   ,'  ,/
 \. ". L_r'
   `~\/
      |
      |""")
# Out:
#          ,r'"7
# r`-_   ,'  ,/
#  \. ". L_r'
#    `~\/
#       |
#       |
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\wogus\AppData\Local\Temp\ipykernel_36600\2731652757.py:1: SyntaxWarning: invalid escape sequence '\.'
#   print("""         ,r'"7
